# %% [markdown]
# ## Fetch Twitter data from APIs

# %% [markdown]
# ### Attempt twitter fetch APIs

# %%
# Data fetcher APIs
import tweepy
import GetOldTweets3 as got

import pandas as pd
import dask.dataframe as dd
import dask

import numpy as np
import matplotlib.pyplot as plt

import re

# %% [markdown]
# ### Attempt Twitter API

# %%
twitter_credentials = pd.read_csv('twitter_keys.csv')
consumer_key = twitter_credentials['API_KEY'][0]
consumer_secret = twitter_credentials['API_KEY_SECRET'][0]
bearer_token = twitter_credentials['BEARER_TOKEN'][0]
access_token = twitter_credentials['ACCESS_TOKEN'][0]
access_token_secret = twitter_credentials['ACCESS_TOKEN_SECRET'][0]

# %%
auth = tweepy.OAuth2BearerHandler(bearer_token)
api = tweepy.API(auth)

# %%
# Filter out retweets
search_term = '#bitcoin -filter:retweets'

tweets = tweepy.Cursor(
    api.search_tweets,
    q=search_term,
    lang='en',
#     since='2018-01-01',
    tweet_mode='extended'
).items(2000)

# %%
all_tweets = [tweet.full_text for tweet in tweets]

# %%
len(all_tweets)
# Out:
# 2000

# %% [markdown]
# **Cannot use Twitter API as the tweets are limited to only the past 7 days**

# %% [markdown]
# ### Attempt GOT package

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(search_term)\
                                           .setSince("2019-03-29")\

tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# An error occured during an HTTP request: HTTP Error 403: Forbidden
# Try to open in browser: https://twitter.com/search?q=%23bitcoin%20-filter%3Aretweets%20since%3A2019-03-29&src=typd
# Traceback (most recent call last):
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\GetOldTweets3\manager\TweetManager.py", line 343, in getJsonResponse
#     response = opener.open(url)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_15508\701950963.py", line 4, in <module>
#     tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\GetOldTweets3\manager\TweetManager.py", line 65, in getTweets
#     json = TweetManager.getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, user_agent, debug=debug)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\GetOldTweets3\manager\TweetManager.py", line 348, in getJsonResponse
#     sys.exit()
# SystemExit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\acer\appdata\local\programs\python\python37\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\GetOldTweets3\manager\TweetManager.py in getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, useragent, debug)
#     342         try:
# --> 343             response = opener.open(url)
#     344             jsonResponse = response.read()
#
# c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# c:\users\acer\appdata\local\programs\python\python37\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_15508\701950963.py in <module>
#       3
# ----> 4 tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\GetOldTweets3\manager\TweetManager.py in getTweets(tweetCriteria, receiveBuffer, bufferLength, proxy, debug)
#      64             while active:
# ---> 65                 json = TweetManager.getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, user_agent, debug=debug)
#      66                 if len(json['items_html'].strip()) == 0:
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\GetOldTweets3\manager\TweetManager.py in getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, useragent, debug)
#     347             print("Try to open in browser: https://twitter.com/search?q=%s&src=typd" % urllib.parse.quote(urlGetData))
# --> 348             sys.exit()
#     349
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2080                            'the full traceback.\n']
#    2081                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2082                                                                      value))
#    2083                 else:
#    2084                     try:
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# Also rendered useless due to the Twitter restrictions

# %% [markdown]
# ### Kaggle dataset
#
# * [data small](https://www.kaggle.com/datasets/kaushiksuresh147/bitcoin-tweets)
#   * Tweets of feb 5th 2021 - Oct 15th 2022 (inclusive, but not all included)
# * [data large](https://www.kaggle.com/datasets/alaix14/bitcoin-tweets-20160101-to-20190329)
#   * Tweets of jan 2nd 2014 - nov 23rd 2019 (inclusive)

# %% [markdown]
# *Attempt pandas*

# %%
df_small = pd.read_csv('../../data/Bitcoin_tweets.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     225                 # destructive to chunks
# --> 226                 data = _concatenate_chunks(chunks)
#     227
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in _concatenate_chunks(chunks)
#     354     for name in names:
# --> 355         arrs = [chunk.pop(name) for chunk in chunks]
#     356         # Check each arr for consistent types.
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in <listcomp>(.0)
#     354     for name in names:
# --> 355         arrs = [chunk.pop(name) for chunk in chunks]
#     356         # Check each arr for consistent types.
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14876\714435790.py in <module>
# ----> 1 df = pd.read_csv('../../data/Bitcoin_tweets.csv')
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in __exit__(self, exc_type, exc_value, traceback)
#    1078
#    1079     def __exit__(self, exc_type, exc_value, traceback):
# -> 1080         self.close()
#    1081
#    1082
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\readers.py in close(self)
#     812
#     813     def close(self):
# --> 814         self._engine.close()
#     815
#     816     def _get_options_with_defaults(self, engine):
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in close(self)
#     190
#     191     def close(self) -> None:
# --> 192         super().close()
#     193
#     194         # close additional handles opened by C parser
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers\base_parser.py in close(self)
#     280     def close(self):
#     281         if self.handles is not None:
# --> 282             self.handles.close()
#     283
#     284     @final
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in close(self)
#     110         try:
#     111             for handle in self.created_handles:
# --> 112                 handle.close()
#     113         except (OSError, ValueError):
#     114             pass
#
# KeyboardInterrupt:

# %% [markdown]
# Pandas takes so long and errors out

# %% [markdown]
# *Attempt dask*

# %%
df_small = dd.read_csv(
    '../../data/Bitcoin_tweets.csv',
    usecols=['user_name', 'user_description', 'date', 'text', 'hashtags']
)

# %%
df_small.head()
# Out:
#                                   user_name  \
# 0                             DeSota Wilson
# 1                                  CryptoND
# 2                                 Tdlmatias
# 3                      Crypto is the future
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
#
#                                     user_description                 date  \
# 0  Biz Consultant, real estate, fintech, startups...  2021-02-10 23:59:04
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2021-02-10 23:58:48
# 2  IM Academy : The best #forex, #SelfEducation, ...  2021-02-10 23:54:48
# 3  I will post a lot of buying signals for BTC tr...  2021-02-10 23:54:33
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...  2021-02-10 23:54:06
#
#                                                 text  \
# 0  Blue Ridge Bank shares halted by NYSE after #b...
# 1  😎 Today, that's this #Thursday, we will do a "...
# 2  Guys evening, I have read this article about B...
# 3  $BTC A big chance in a billion! Price: \487264...
# 4  This network is secured by 9 508 nodes as of t...
#
#                                     hashtags
# 0                                ['bitcoin']
# 1  ['Thursday', 'Btc', 'wallet', 'security']
# 2                                        NaN
# 3         ['Bitcoin', 'FX', 'BTC', 'crypto']
# 4                                    ['BTC']

# %% [markdown]
# Was able to read the small dataset, attempt large

# %%
df_large = dd.read_csv(
    '../../data/Bitcoin_tweets_large.csv',
    delimiter=';',
    usecols=['user', 'fullname', 'timestamp', 'text'],
    engine='python',
    on_bad_lines='skip'
)

# %%
df_large.head()
# Out:
#             user             fullname               timestamp  \
# 0   KamdemAbdiel        Abdiel kamdem  2019-05-27 11:49:14+00
# 1      bitcointe            Bitcointe  2019-05-27 11:49:18+00
# 2      3eyedbran  Bran - 3 Eyed Raven  2019-05-27 11:49:06+00
# 3  DetroitCrypto          J. Scardina  2019-05-27 11:49:22+00
# 4   mmursaleen72   Muhammad Mursaleen  2019-05-27 11:49:23+00
#
#                                                 text
# 0  È appena uscito un nuovo video! LES CRYPTOMONN...
# 1  Cardano: Digitize Currencies; EOS https://t.co...
# 2  Another Test tweet that wasn't caught in the s...
# 3  Current Crypto Prices! \n\nBTC: $8721.99 USD\n...
# 4  Spiv (Nosar Baz): BITCOIN Is An Asset &amp; NO...

# %%
df_large['timestamp'] = dd.to_datetime(df_large['timestamp'])

# %%
df_large.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 4 entries, user to text
# dtypes: datetime64[ns](1), object(3)

# %%
# Check if any null timestamps
df_large['timestamp'].isnull().sum().compute()
# Out:
# 823

# %%
df_large.size.compute()
# Out:
# 67562152

# %%
# Remove empty timestamp values to facilitate sorting
df_large_cleaned = df_large.dropna(subset=['timestamp'])

# %%
df_large_cleaned.sort_values('timestamp', inplace=True).compute()
# Out:
#                    user                  fullname                 timestamp  \
# 114517     chrispychong                   chrispy 2007-04-19 07:14:38+00:00
# 21               halfin                    halfin 2009-01-11 03:33:52+00:00
# 45666            halfin                    halfin 2009-01-21 17:29:40+00:00
# 91597            halfin                    halfin 2009-01-27 20:14:10+00:00
# 18020       fafcffacfff                 GoldLover 2009-01-29 13:37:53+00:00
# ...                 ...                       ...                       ...
# 139141    theautomatski                Automatski 2019-11-23 15:45:53+00:00
# 139143    digital_mine_  digital mine ⚡🤖👨‍💻🇭🇰🇭🇰🇭🇰 2019-11-23 15:45:55+00:00
# 139145          Vizique                   Vizique 2019-11-23 15:45:55+00:00
# 139146         torusJKL      Gal Buki ($torusJKL) 2019-11-23 15:45:56+00:00
# 139147  Adekunl95628158           Adekunle Daniel 2019-11-23 15:45:57+00:00
#
#                                                      text
# 114517  is happily mugging at BTC where she will hook ...
# 21                                        Running bitcoin
# 45666    Looking at ways to add more anonymity to bitcoin
# 91597   Thinking about how to reduce CO2 emissions fro...
# 18020   From: Satoshi Nakamoto - 2009-01-11 22:32 Bitc...
# ...                                                   ...
# 139141  The Worlds First Millennium Firm https://t.co/...
# 139143  Daily profit for HODLING BTC since 2013 Data t...
# 139145  Bitcoin Suisse Certificates :) https://t.co/nd...
# 139146  Register now for the early access of the Codug...
# 139147  @btc \n@btc \nDo you know that BTC Baskets isn...
#
# [16889715 rows x 4 columns]

# %%
df_large_cleaned.tail()
# Out:
#                    user              fullname                 timestamp  \
# 139144    JacobCanfield        Jacob Canfield 2019-11-23 15:28:50+00:00
# 139145          Vizique               Vizique 2019-11-23 15:45:55+00:00
# 139146         torusJKL  Gal Buki ($torusJKL) 2019-11-23 15:45:56+00:00
# 139147  Adekunl95628158       Adekunle Daniel 2019-11-23 15:45:57+00:00
# 139148       HaraldoXRP                 Harry 2019-11-23 15:45:06+00:00
#
#                                                      text
# 139144  Happy #FibonacciDay \n\nA while back I created...
# 139145  Bitcoin Suisse Certificates :) https://t.co/nd...
# 139146  Register now for the early access of the Codug...
# 139147  @btc \n@btc \nDo you know that BTC Baskets isn...
# 139148  $BTC - an update on the longer term view for B...

# %%
# Remove unneeded time section
df_large_cleaned['timestamp'] = df_2_cleaned['timestamp'].dt.strftime('%m/%d/%Y')

# %%
df_large_cleaned.head()
# Out:
#             user             fullname   timestamp  \
# 0   KamdemAbdiel        Abdiel kamdem  05/27/2019
# 1      bitcointe            Bitcointe  05/27/2019
# 2      3eyedbran  Bran - 3 Eyed Raven  05/27/2019
# 3  DetroitCrypto          J. Scardina  05/27/2019
# 4   mmursaleen72   Muhammad Mursaleen  05/27/2019
#
#                                                 text
# 0  È appena uscito un nuovo video! LES CRYPTOMONN...
# 1  Cardano: Digitize Currencies; EOS https://t.co...
# 2  Another Test tweet that wasn't caught in the s...
# 3  Current Crypto Prices! \n\nBTC: $8721.99 USD\n...
# 4  Spiv (Nosar Baz): BITCOIN Is An Asset &amp; NO...

# %%
df_large_cleaned.tail()
# Out:
#                    user              fullname   timestamp  \
# 139144    JacobCanfield        Jacob Canfield  11/23/2019
# 139145          Vizique               Vizique  11/23/2019
# 139146         torusJKL  Gal Buki ($torusJKL)  11/23/2019
# 139147  Adekunl95628158       Adekunle Daniel  11/23/2019
# 139148       HaraldoXRP                 Harry  11/23/2019
#
#                                                      text
# 139144  Happy #FibonacciDay \n\nA while back I created...
# 139145  Bitcoin Suisse Certificates :) https://t.co/nd...
# 139146  Register now for the early access of the Codug...
# 139147  @btc \n@btc \nDo you know that BTC Baskets isn...
# 139148  $BTC - an update on the longer term view for B...

# %%
df_large_cleaned.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 4 entries, user to text
# dtypes: object(4)

# %%
# Filter old data
df_large_filtered = df_large_cleaned[df_large_cleaned['timestamp'] > '01/01/2014']

# %%
df_large_filtered.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 4 entries, user to text
# dtypes: object(4)

# %%
df_large_filtered.size.compute()
# Out:
# 67554192

# %%
# Set date as index to repartition
df_large_filtered_indexed = df_large_filtered.set_index('timestamp')

# %%
df_large_filtered_indexed.head()
# Out:
#                       user          fullname  \
# timestamp
# 01/01/2015       BTCticker  bitcointicker.co
# 01/01/2015     ProjectCoin      Project Coin
# 01/01/2015     airdroplite      Airdrop Lite
# 01/01/2015       BTCticker  bitcointicker.co
# 01/01/2015  BitcoinSpreads   Bitcoin Spreads
#
#                                                          text
# timestamp
# 01/01/2015  One Bitcoin now worth $315.63@bitstamp. High $...
# 01/01/2015  LIVE: Profit = $712.36 (27.66 %). BUY B8.16 @ ...
# 01/01/2015  BTCTurk 762.55 TL Koinim 770 TL CampBx 330.00 ...
# 01/01/2015  One Bitcoin now worth $314.75@bitstamp. High $...
# 01/01/2015  1 #BTC (#Bitcoin) quotes:\n$314.62/$315.00 #Bi...

# %%
df_large_filtered_indexed.tail()
# Out:
#                       user             fullname  \
# timestamp
# 12/31/2018       Uberbills        Uberbills.com
# 12/31/2018     bt_exchange  Bitcoin Exchange BR
# 12/31/2018  BitcoinCash_ES       BitcoinCash_es
# 12/31/2018       asens_inc           ASENS inc.
# 12/31/2018   short_vs_long  SHORT vs LONG(Beta)
#
#                                                          text
# timestamp
# 12/31/2018  BTC: $3751.00, S: $Looking Fo, G: $ Spot Pric ...
# 12/31/2018  1 BTC = 15228.57976000 BRL em 31/12/2018 ás 12...
# 12/31/2018  Cotización del Bitcoin Cash: 136 80.€ | -0.15%...
# 12/31/2018  12/31 23:00現在\n\n#Bitcoin : 410,395円↓\n#NEM #X...
# 12/31/2018  24H\n2019/01/01 02:00 (2018/12/31 01:59)\nLONG...

# %%
# Dataframe is extremely large - split into chunks
df_large_repartitioned = df_large_filtered_indexed.repartition(partition_size='100MB')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14876\554367951.py in <module>
#       1 # Dataframe is extremely large - split into chunks
# ----> 2 df_2_repartitioned = df_2_sorted_copy_indexed.repartition(freq='1D')
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'repartition'

# %%
df_2_repartitioned.to_csv('../../data/dataframes/data-*.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14876\234911602.py in <module>
# ----> 1 df_3.to_csv('../../data/dataframes/data-*.csv')
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\dask\dataframe\core.py in to_csv(self, filename, **kwargs)
#    1558         from .io import to_csv
#    1559
# -> 1560         return to_csv(self, filename, **kwargs)
#    1561
#    1562     def to_sql(
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\dask\dataframe\io\csv.py in to_csv(df, filename, single_file, encoding, mode, name_function, compression, compute, scheduler, storage_options, header_first_partition_only, compute_kwargs, **kwargs)
#     955         import dask
#     956
# --> 957         return list(dask.compute(*values, **compute_kwargs))
#     958     else:
#     959         return values
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\dask\base.py in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     571         postcomputes.append(x.__dask_postcompute__())
#     572
# --> 573     results = schedule(dsk, keys, **kwargs)
#     574     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     575
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      87         get_id=_thread_get_id,
#      88         pack_exception=pack_exception,
# ---> 89         **kwargs,
#      90     )
#      91
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\dask\local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     493             while state["waiting"] or state["ready"] or state["running"]:
#     494                 fire_tasks(chunksize)
# --> 495                 for key, res_info, failed in queue_get(queue).result():
#     496                     if failed:
#     497                         exc, tb = loads(res_info)
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\dask\local.py in queue_get(q)
#     124         while True:
#     125             try:
# --> 126                 return q.get(block=True, timeout=0.1)
#     127             except Empty:
#     128                 pass
#
# c:\users\acer\appdata\local\programs\python\python37\lib\queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# c:\users\acer\appdata\local\programs\python\python37\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ```
# Process limited by available memory -> Moving to Kaggle as it has 30GB RAM
#
# break_file_chunks.ipynb - discontinued
# bitcoin_tweets_filteration_large.ipynb
# bitcoin_tweets_filteration_small.ipynb
#
# ```

# %% [markdown]
# ***
# A wide range of CSV's have been created, each for each individual day. However, the `bitcoin_tweets_filteration_small.ipynb` scraper does not contain all the dates between the two ranges... which is a significant issue, and requires scraping

# %% [markdown]
# ### check which dates are missing till last available date

# %%
from datetime import date, timedelta
import os

start_date = date(2014, 1, 2) 
end_date = date(2022, 10, 15)
delta = end_date - start_date
days = []

for i in range(delta.days + 1):
    day = start_date + timedelta(days=i)
    days.append(day)

# %%
available_days_small = os.listdir('../../../data/Tweets/broken_small_sets_limited')
available_days_large = os.listdir('../../../data/Tweets/broken_large_sets_limited')

# %%
available_days_small = [day.replace('.csv', '') for day in available_days_small]
available_days_large = [day.replace('.csv', '') for day in available_days_large]

available_days_small[:10], available_days_large[:10]
# Out:
# (['2021-02-05',
#   '2021-02-06',
#   '2021-02-07',
#   '2021-02-08',
#   '2021-02-09',
#   '2021-02-10',
#   '2021-02-13',
#   '2021-02-14',
#   '2021-02-15',
#   '2021-02-18'],
#  ['2014-01-02',
#   '2014-01-03',
#   '2014-01-04',
#   '2014-01-05',
#   '2014-01-06',
#   '2014-01-07',
#   '2014-01-08',
#   '2014-01-09',
#   '2014-01-10',
#   '2014-01-11'])

# %%
available_days = available_days_small + available_days_large
available_days[:10]
# Out:
# ['2021-02-05',
#  '2021-02-06',
#  '2021-02-07',
#  '2021-02-08',
#  '2021-02-09',
#  '2021-02-10',
#  '2021-02-13',
#  '2021-02-14',
#  '2021-02-15',
#  '2021-02-18']

# %%
days = [str(day) for day in days]
days[:10]
# Out:
# ['2014-01-02',
#  '2014-01-03',
#  '2014-01-04',
#  '2014-01-05',
#  '2014-01-06',
#  '2014-01-07',
#  '2014-01-08',
#  '2014-01-09',
#  '2014-01-10',
#  '2014-01-11']

# %%
missing_days = [day for day in days if day not in available_days]
missing_days[:10]
# Out:
# ['2019-11-24',
#  '2019-11-25',
#  '2019-11-26',
#  '2019-11-27',
#  '2019-11-28',
#  '2019-11-29',
#  '2019-11-30',
#  '2019-12-01',
#  '2019-12-02',
#  '2019-12-03']

# %%
len(missing_days), len(available_days), len(days)
# Out:
# (854, 2359, 3209)

# %% [markdown]
# ```
# Attempt fetching tweets of missing dates on tweet_scraper.ipynb -> Attempted in Kaggle due to better computation power
# ```

# %%
# Save list of missing days to load into Kaggle kernel
with open(r'../../../data/tweets/broken_small_sets_limited/missing_days.txt', 'w') as fp:
    for day in missing_days:
        fp.write("%s\n" % day)
    print('Done')
# Out:
# Done

# %% [markdown]
# **Data scraped within `tweet_scraper.ipynb` check which dates are still missing**

# %%
with open('../../../data/tweets/broken_small_sets_limited/missing_days.txt') as f:
    missing_days = [line.replace('\n', '') for line in f.readlines()]

# %%
missing_days
# Out:
# ['2019-11-24',
#  '2019-11-25',
#  '2019-11-26',
#  '2019-11-27',
#  '2019-11-28',
#  '2019-11-29',
#  '2019-11-30',
#  '2019-12-01',
#  '2019-12-02',
#  '2019-12-03',
#  '2019-12-04',
#  '2019-12-05',
#  '2019-12-06',
#  '2019-12-07',
#  '2019-12-08',
#  '2019-12-09',
#  '2019-12-10',
#  '2019-12-11',
#  '2019-12-12',
#  '2019-12-13',
#  '2019-12-14',
#  '2019-12-15',
#  '2019-12-16',
#  '2019-12-17',
#  '2019-12-18',
#  '2019-12-19',
#  '2019-12-20',
#  '2019-12-21',
#  '2019-12-22',
#  '2019-12-23',
#  '2019-12-24',
#  '2019-12-25',
#  '2019-12-26',
#  '2019-12-27',
#  '2019-12-28',
#  '2019-12-29',
#  '2019-12-30',
#  '2019-12-31',
#  '2020-01-01',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-04',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-08',
#  '2020-01-09',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2022-08-11',
#  '2022-08-12',
#  '2022-08-13',
#  '2022-08-14',
#  '2022-08-15',
#  '2022-08-16',
#  '2022-08-17',
#  '2022-08-18',
#  '2022-08-19',
#  '2022-08-20',
#  '2022-08-21',
#  '2022-08-22',
#  '2022-08-23',
#  '2022-08-24',
#  '2022-08-25',
#  '2022-08-26',
#  '2022-08-27',
#  '2022-08-28',
#  '2022-08-29',
#  '2022-09-05',
#  '2022-09-06',
#  '2022-09-07',
#  '2022-09-08',
#  '2022-09-09',
#  '2022-09-10',
#  '2022-09-15',
#  '2022-09-16',
#  '2022-09-17',
#  '2022-09-18',
#  '2022-09-19',
#  '2022-09-20',
#  '2022-09-21',
#  '2022-09-22',
#  '2022-09-23',
#  '2022-09-24',
#  '2022-09-25',
#  '2022-09-26',
#  '2022-09-27',
#  '2022-09-28',
#  '2022-09-29',
#  '2022-09-30',
#  '2022-10-01',
#  '2022-10-02',
#  '2022-10-03',
#  '2022-10-04',
#  '2022-10-05',
#  '2022-10-06',
#  '2022-10-07',
#  '2022-10-08']

# %%
import os
scraped_days = os.listdir('../../../data/Tweets/tweets_scraped/total')

# %%
scraped_days = [day.replace('.csv', '') for day in scraped_days]
scraped_days
# Out:
# ['2019-11-24',
#  '2019-11-25',
#  '2019-11-26',
#  '2019-11-27',
#  '2019-11-28',
#  '2019-11-29',
#  '2019-11-30',
#  '2019-12-01',
#  '2019-12-02',
#  '2019-12-03',
#  '2019-12-04',
#  '2019-12-05',
#  '2019-12-06',
#  '2019-12-07',
#  '2019-12-08',
#  '2019-12-09',
#  '2019-12-10',
#  '2019-12-11',
#  '2019-12-12',
#  '2019-12-13',
#  '2019-12-14',
#  '2019-12-15',
#  '2019-12-16',
#  '2019-12-17',
#  '2019-12-18',
#  '2019-12-19',
#  '2019-12-20',
#  '2019-12-21',
#  '2019-12-22',
#  '2019-12-23',
#  '2019-12-24',
#  '2019-12-25',
#  '2019-12-26',
#  '2019-12-27',
#  '2019-12-28',
#  '2019-12-29',
#  '2019-12-30',
#  '2019-12-31',
#  '2020-01-01',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-04',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-08',
#  '2020-01-09',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-11-25',
#  '2020-11-26',
#  '2020-11-27',
#  '2020-11-28',
#  '2020-11-29',
#  '2020-11-30',
#  '2020-12-01',
#  '2020-12-02',
#  '2020-12-03',
#  '2020-12-04',
#  '2020-12-05',
#  '2020-12-06',
#  '2020-12-07',
#  '2020-12-08',
#  '2020-12-09',
#  '2020-12-10',
#  '2020-12-11',
#  '2020-12-12',
#  '2020-12-13',
#  '2020-12-14',
#  '2020-12-15',
#  '2020-12-16',
#  '2020-12-17',
#  '2020-12-18',
#  '2020-12-19',
#  '2020-12-20',
#  '2020-12-21',
#  '2020-12-22',
#  '2020-12-23',
#  '2020-12-24',
#  '2020-12-25',
#  '2020-12-26',
#  '2020-12-27',
#  '2020-12-28',
#  '2020-12-29',
#  '2020-12-30',
#  '2020-12-31',
#  '2021-01-01',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-10',
#  '2021-02-11',
#  '2021-02-15',
#  '2021-02-16',
#  '2021-02-19',
#  '2021-02-20',
#  '2021-02-22',
#  '2021-02-23',
#  '2021-02-24',
#  '2021-02-25',
#  '2021-02-26',
#  '2021-02-28',
#  '2021-03-01',
#  '2021-03-02',
#  '2021-03-03',
#  '2021-03-04',
#  '2021-03-05',
#  '2021-03-06',
#  '2021-03-07',
#  '2021-03-08',
#  '2021-03-09',
#  '2021-03-12',
#  '2021-03-13',
#  '2021-03-14',
#  '2021-03-15',
#  '2021-03-16',
#  '2021-03-17',
#  '2021-03-18',
#  '2021-03-19',
#  '2021-03-20',
#  '2021-03-21',
#  '2021-03-22',
#  '2021-03-23',
#  '2021-03-24',
#  '2021-03-25',
#  '2021-03-26',
#  '2021-03-27',
#  '2021-03-28',
#  '2021-03-29',
#  '2021-03-30',
#  '2021-03-31',
#  '2021-04-01',
#  '2021-04-02',
#  '2021-04-03',
#  '2021-04-12',
#  '2021-04-13',
#  '2021-04-14',
#  '2021-04-15',
#  '2021-04-24',
#  '2021-04-25',
#  '2021-04-26',
#  '2021-04-27',
#  '2021-04-28',
#  '2021-04-29',
#  '2021-04-30',
#  '2021-05-01',
#  '2021-05-02',
#  '2021-05-03',
#  '2021-05-04',
#  '2021-05-05',
#  '2021-05-06',
#  '2021-05-08',
#  '2021-05-09',
#  '2021-05-10',
#  '2021-05-11',
#  '2021-05-12',
#  '2021-05-13',
#  '2021-05-14',
#  '2021-05-15',
#  '2022-07-28',
#  '2022-07-29',
#  '2022-07-30',
#  '2022-07-31',
#  '2022-08-01',
#  '2022-08-02',
#  '2022-08-03',
#  '2022-08-04',
#  '2022-08-05',
#  '2022-08-06',
#  '2022-08-07',
#  '2022-08-08',
#  '2022-08-09',
#  '2022-08-10',
#  '2022-08-11',
#  '2022-08-12',
#  '2022-08-13',
#  '2022-08-14',
#  '2022-08-15',
#  '2022-08-16',
#  '2022-08-17',
#  '2022-08-18',
#  '2022-08-19',
#  '2022-08-20',
#  '2022-08-21',
#  '2022-08-22',
#  '2022-08-23',
#  '2022-08-24',
#  '2022-08-25',
#  '2022-08-26',
#  '2022-08-27',
#  '2022-08-28',
#  '2022-09-04',
#  '2022-09-05',
#  '2022-09-06',
#  '2022-09-07',
#  '2022-09-08',
#  '2022-09-09',
#  '2022-09-14',
#  '2022-09-15',
#  '2022-09-16',
#  '2022-09-17',
#  '2022-09-18',
#  '2022-09-19',
#  '2022-09-20',
#  '2022-09-21',
#  '2022-09-22',
#  '2022-09-23',
#  '2022-09-24',
#  '2022-09-25',
#  '2022-09-26',
#  '2022-09-27',
#  '2022-09-28',
#  '2022-09-29',
#  '2022-09-30',
#  '2022-10-01',
#  '2022-10-02',
#  '2022-10-03',
#  '2022-10-04',
#  '2022-10-05',
#  '2022-10-06',
#  '2022-10-07']

# %%
still_missing_days = [day for day in missing_days if day not in scraped_days]

# %%
still_missing_days
# Out:
# ['2020-09-18',
#  '2021-02-04',
#  '2021-02-12',
#  '2021-02-17',
#  '2021-02-21',
#  '2021-02-27',
#  '2021-03-10',
#  '2021-04-04',
#  '2021-04-16',
#  '2021-05-07',
#  '2021-05-24',
#  '2021-06-19',
#  '2021-07-01',
#  '2021-07-15',
#  '2021-08-03',
#  '2021-08-13',
#  '2021-08-22',
#  '2021-09-09',
#  '2021-10-17',
#  '2021-10-26',
#  '2021-11-03',
#  '2021-11-10',
#  '2021-11-17',
#  '2021-11-23',
#  '2021-12-10',
#  '2021-12-16',
#  '2021-12-28',
#  '2022-01-10',
#  '2022-01-18',
#  '2022-02-08',
#  '2022-02-10',
#  '2022-02-13',
#  '2022-03-01',
#  '2022-03-05',
#  '2022-03-13',
#  '2022-04-12',
#  '2022-04-26',
#  '2022-05-09',
#  '2022-05-21',
#  '2022-06-13',
#  '2022-06-16',
#  '2022-06-22',
#  '2022-06-27',
#  '2022-07-01',
#  '2022-07-10',
#  '2022-08-29',
#  '2022-09-10',
#  '2022-10-08']

# %%
len(still_missing_days), len(missing_days), len(scraped_days)
# Out:
# (48, 854, 850)

# %%
# Save list of missing days to load into Kaggle kernel
with open(r'../../../data/tweets/still_missing_days.txt', 'w') as fp:
    for day in still_missing_days:
        fp.write("%s\n" % day)
    print('Done')
# Out:
# Done

# %%
# Check again
scraped_days = os.listdir('../../../data/Tweets/tweets_scraped/total')

# %%
scraped_days = [day.replace('.csv', '') for day in scraped_days]
still_missing_days = [day for day in missing_days if day not in scraped_days]

# %%
still_missing_days
# Out:
# []

# %% [markdown]
# Perfect. Everything is obtained till the specified date
